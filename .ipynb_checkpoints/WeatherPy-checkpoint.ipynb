# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
weather_api_key
# Out:
# 'ce05151347571195cff46ac169e11d17'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 632

# %%
cities
# Out:
# ['saskylakh',
#  'barentsburg',
#  'catalina',
#  'kamenka',
#  'busselton',
#  'manta',
#  'tutoia',
#  'huanren',
#  'ushuaia',
#  'vega de alatorre',
#  'katsiveli',
#  'krumbach',
#  'dhidhdhoo',
#  'qaanaaq',
#  'lamar',
#  'mataura',
#  'caravelas',
#  'hobyo',
#  'bethel',
#  'longlac',
#  'samalaeulu',
#  'progreso',
#  'kieta',
#  'faanui',
#  'kapaa',
#  'jamestown',
#  'sentyabrskiy',
#  'taolanaro',
#  'sekondi',
#  'severo-kurilsk',
#  'rikitea',
#  'saint-francois',
#  'albany',
#  'hobart',
#  'san carlos de bariloche',
#  'barrow',
#  'guerrero negro',
#  'hilo',
#  'new norfolk',
#  'codrington',
#  'carnarvon',
#  'puerto escondido',
#  'koyilandi',
#  'dikson',
#  'tuktoyaktuk',
#  'praya',
#  'mehamn',
#  'sabha',
#  'fortuna',
#  'poronaysk',
#  'hirara',
#  'necochea',
#  'charters towers',
#  'bathsheba',
#  'saint-philippe',
#  'buala',
#  'hammerfest',
#  'lagunas',
#  'nguiu',
#  'georgetown',
#  'vila velha',
#  'sibolga',
#  'berbera',
#  'katsuura',
#  'cherskiy',
#  'alyangula',
#  'east london',
#  'agucadoura',
#  'cape town',
#  'san luis',
#  'gallup',
#  'tabiauea',
#  'chokurdakh',
#  'bluff',
#  'bouna',
#  'alta floresta',
#  'luoyang',
#  'grindavik',
#  'illoqqortoormiut',
#  'prince rupert',
#  'bilibino',
#  'saleaula',
#  'amderma',
#  'ruatoria',
#  'port alfred',
#  'qui nhon',
#  'dire dawa',
#  'nouakchott',
#  'souillac',
#  'serta',
#  'hithadhoo',
#  'vaitupu',
#  'raga',
#  'upernavik',
#  'mittagong',
#  'ostrovnoy',
#  'lagoa',
#  'kaitangata',
#  'kodiak',
#  'tasiilaq',
#  'rovenki',
#  'manoel urbano',
#  'atuona',
#  'antalaha',
#  'kamenskoye',
#  'bambous virieux',
#  'belushya guba',
#  'arraial do cabo',
#  'puerto maldonado',
#  'marawi',
#  'bolungarvik',
#  'gorontalo',
#  'narsaq',
#  'castro',
#  'udachnyy',
#  'lafia',
#  'ponta do sol',
#  'xining',
#  'kudahuvadhoo',
#  'victoria',
#  'toora-khem',
#  'marcona',
#  'geraldton',
#  'nizhneyansk',
#  'palabuhanratu',
#  'hasaki',
#  'khatanga',
#  'rocha',
#  'tsihombe',
#  'punta arenas',
#  'midland',
#  'grand-santi',
#  'chuy',
#  'port hedland',
#  'villazon',
#  'dingle',
#  'bontang',
#  'nikolskoye',
#  'yar-sale',
#  'kosa',
#  'provideniya',
#  'boa vista',
#  'butaritari',
#  'sulangan',
#  'north myrtle beach',
#  'port elizabeth',
#  'vardo',
#  'touros',
#  'san quintin',
#  'port-gentil',
#  'axim',
#  'morehead',
#  'airai',
#  'nouadhibou',
#  'sao joao da barra',
#  'asind',
#  'kanniyakumari',
#  'guarapari',
#  'megion',
#  'nemuro',
#  'atambua',
#  'sioux lookout',
#  'vestmannaeyjar',
#  'kharitonovo',
#  'zuwarah',
#  'sitka',
#  'paka',
#  'ouesso',
#  'moree',
#  'yellowknife',
#  'haines junction',
#  'lavrentiya',
#  'antimakhia',
#  'neiafu',
#  'maralal',
#  'chagda',
#  'yulara',
#  'mar del plata',
#  'mahebourg',
#  'omsukchan',
#  'te anau',
#  'port keats',
#  'causapscal',
#  'berdigestyakh',
#  'lorengau',
#  'alofi',
#  'bredasdorp',
#  'hamilton',
#  'zarand',
#  'puerto ayora',
#  'saint anthony',
#  'les cayes',
#  'berlevag',
#  'ancud',
#  'tuatapere',
#  'tevriz',
#  'road town',
#  'luderitz',
#  'goderich',
#  'mollendo',
#  'le vauclin',
#  'solnechnyy',
#  'russkaya polyana',
#  'constitucion',
#  'moindou',
#  'luwuk',
#  'oktyabrskiy',
#  'ibb',
#  'tsienyane',
#  'kampene',
#  'toma',
#  'umzimvubu',
#  'zhigansk',
#  'grand river south east',
#  'fredericksburg',
#  'madison',
#  'attawapiskat',
#  'huarmey',
#  'ribas do rio pardo',
#  'fallon',
#  'aripuana',
#  'khonuu',
#  'vaini',
#  'doctor cecilio baez',
#  'brae',
#  'broome',
#  'kruisfontein',
#  'cidreira',
#  'ayutuxtepeque',
#  'talnakh',
#  'pevek',
#  'bonthe',
#  'wajima',
#  'coihaique',
#  'kurilsk',
#  'kapit',
#  'mapimi',
#  'thompson',
#  'mogadishu',
#  'karratha',
#  'mys shmidta',
#  'armacao dos buzios',
#  'nabire',
#  'colborne',
#  'nhulunbuy',
#  'verkhnetulomskiy',
#  'lebu',
#  'wronki',
#  'kirensk',
#  'saquisili',
#  'san policarpo',
#  'tiksi',
#  'hermanus',
#  'saint george',
#  'naze',
#  'pangnirtung',
#  'la ronge',
#  'itacoatiara',
#  'finschhafen',
#  'copiapo',
#  'holme',
#  'nanortalik',
#  'tecate',
#  'omboue',
#  'esperance',
#  'alpena',
#  'kollam',
#  'namibe',
#  'lahuachaca',
#  'saint-joseph',
#  'were ilu',
#  'tahe',
#  'ballina',
#  'seoul',
#  'aklavik',
#  'kazalinsk',
#  'zyryanka',
#  'vangaindrano',
#  'bay roberts',
#  'thousand oaks',
#  'lima',
#  'grants',
#  'correntina',
#  'lakes entrance',
#  'amot',
#  'huazolotitlan',
#  'mersing',
#  'kankakee',
#  'dhrangadhra',
#  'beringovskiy',
#  'elbistan',
#  'lovozero',
#  'amarillo',
#  'oistins',
#  'cache creek',
#  'xai-xai',
#  'altamira',
#  'chapais',
#  'klamath falls',
#  'halalo',
#  'yeppoon',
#  'fairbanks',
#  'maniitsoq',
#  'thunder bay',
#  'klaksvik',
#  'kutum',
#  'deputatskiy',
#  'qinzhou',
#  'bell ville',
#  'bandarbeyla',
#  'ngukurr',
#  'camabatela',
#  'san lorenzo',
#  'sorland',
#  'nanjangud',
#  'sechura',
#  'pedro carbo',
#  'hof',
#  'warqla',
#  'clyde river',
#  'cabo san lucas',
#  'key largo',
#  'chiredzi',
#  'half moon bay',
#  'wynyard',
#  'rapid valley',
#  'verkhoyansk',
#  'benghazi',
#  'jinchang',
#  'okato',
#  'launceston',
#  'changde',
#  'piterka',
#  'namatanai',
#  'tambura',
#  'kyzyl-suu',
#  'melville',
#  'petropavlovsk-kamchatskiy',
#  'kavaratti',
#  'vera cruz',
#  'saint-pierre',
#  'zlobin',
#  'pacific grove',
#  'black diamond',
#  'bur gabo',
#  'clearwater',
#  'sokolo',
#  'helena',
#  'waingapu',
#  'adrar',
#  'liminangcong',
#  'akdepe',
#  'hambantota',
#  'bodden town',
#  'jawhar',
#  'paradwip',
#  'ricardo palma',
#  'bengkulu',
#  'singkang',
#  'plettenberg bay',
#  'kahului',
#  'ribeira grande',
#  'umm lajj',
#  'terrak',
#  'lasa',
#  'avarua',
#  'carballo',
#  'nkhotakota',
#  'lompoc',
#  'port lincoln',
#  'mayo',
#  'opportunity',
#  'ransang',
#  'amlame',
#  'urubicha',
#  'nola',
#  'sao filipe',
#  'port blair',
#  'emerald',
#  'torbay',
#  'kavieng',
#  'puerto madryn',
#  'nome',
#  'fukue',
#  'salalah',
#  'gazojak',
#  'nantucket',
#  'quzhou',
#  'santa fe',
#  'savelugu',
#  'belaya gora',
#  'partsa',
#  'champerico',
#  'coolum beach',
#  'zhuanghe',
#  'popondetta',
#  'kurchum',
#  'lusambo',
#  'dicabisagan',
#  'nanakuli',
#  'tumannyy',
#  'ganzhou',
#  'helong',
#  'college',
#  'noumea',
#  'martinho campos',
#  'zapolyarnyy',
#  'nioro',
#  'jining',
#  'sangmelima',
#  'sokoni',
#  'ahipara',
#  'nanfeng',
#  'togur',
#  'srednekolymsk',
#  'jagraon',
#  'waddan',
#  'ukiah',
#  'inverell',
#  'olavarria',
#  'gzhatsk',
#  'barao de melgaco',
#  'kamaishi',
#  'la romana',
#  'tessalit',
#  'ratnagiri',
#  'valle de allende',
#  'paamiut',
#  'turan',
#  'dabakala',
#  'abilene',
#  'spearfish',
#  'hovd',
#  'lata',
#  'beloha',
#  'pisco',
#  'copparo',
#  'tahta',
#  'pochutla',
#  'havelock',
#  'yerbogachen',
#  'sataua',
#  'roebourne',
#  'deoli',
#  'mehran',
#  'pangai',
#  'derzhavinsk',
#  'port macquarie',
#  'comodoro rivadavia',
#  'ugoofaaru',
#  'poum',
#  'sisimiut',
#  'dwarka',
#  'jiuquan',
#  'portland',
#  'takoradi',
#  'ilulissat',
#  'vanavara',
#  'zulueta',
#  'rodez',
#  'timbiqui',
#  'cabinda',
#  'hue',
#  'toliary',
#  'roma',
#  'tonj',
#  'havoysund',
#  'nedjo',
#  'lolua',
#  'cap malheureux',
#  'kokoda',
#  'banda aceh',
#  'sebeta',
#  'jatibonico',
#  'yialos',
#  'statesboro',
#  'teknaf',
#  'daru',
#  'gorin',
#  'nosy varika',
#  'sola',
#  'vestmanna',
#  'linhai',
#  'jiroft',
#  'samusu',
#  'lac',
#  'smithers',
#  'turbat',
#  'longyearbyen',
#  'guymon',
#  'vavoua',
#  'shenjiamen',
#  'tabory',
#  'lang son',
#  'isangel',
#  'prachuap khiri khan',
#  'findlay',
#  'chulym',
#  'malwan',
#  'mirnyy',
#  'ust-tsilma',
#  'kirakira',
#  'kenora',
#  'alice springs',
#  'volosovo',
#  'shingu',
#  'yatou',
#  'miranorte',
#  'port augusta',
#  'viedma',
#  'mrirt',
#  'sao miguel',
#  'leshukonskoye',
#  'petatlan',
#  'hofn',
#  'itaqui',
#  'tevaitoa',
#  'hendijan',
#  'quatre cocos',
#  'oxelosund',
#  'khani',
#  'igarka',
#  'upata',
#  'batemans bay',
#  'yagodnoye',
#  'akwatia',
#  'warangal',
#  'nishihara',
#  'cockburn town',
#  'chara',
#  'cheyenne',
#  'jacmel',
#  'nusaybin',
#  'olafsvik',
#  'gorshechnoye',
#  'bilopillya',
#  'colares',
#  'tuggurt',
#  'marsa matruh',
#  'cortez',
#  'castellammare del golfo',
#  'palmer',
#  'ponta delgada',
#  'dano',
#  'kloulklubed',
#  'maldonado',
#  'tomatlan',
#  'abu dhabi',
#  'cessnock',
#  'callaway',
#  'mulege',
#  'bato',
#  'vila do maio',
#  'sobolevo',
#  'ust-kamchatsk',
#  'saldanha',
#  'talaya',
#  'jishou',
#  'vaitape',
#  'quelimane',
#  'bossangoa',
#  'batagay',
#  'ati',
#  'luba',
#  'peniche',
#  'presidencia roque saenz pena',
#  'lambarene',
#  'tunceli',
#  'sao marcos',
#  'slavgorodskoye',
#  'hannoversch munden',
#  'inzhavino',
#  'labuhan',
#  'northam',
#  'duku',
#  'ixtapa',
#  'zhoucheng',
#  'norman wells',
#  'tibacuy',
#  'horsham',
#  'kapasan',
#  'carutapera',
#  'vila franca do campo',
#  'bijar',
#  'aneho',
#  'mattru',
#  'dukat',
#  'egvekinot',
#  'joshimath',
#  'monroe',
#  'macusani',
#  'westpunt',
#  'altinopolis',
#  'dewas',
#  'vanimo',
#  'hami',
#  'temaraia',
#  'dryden',
#  'chino valley',
#  'blyznyuky',
#  'louisbourg',
#  'la ligua',
#  'ambilobe',
#  'henties bay',
#  'ostersund',
#  'agha jari',
#  'luganville',
#  'the pas',
#  'leonidovo',
#  'aracuai',
#  'forbes',
#  'shubarkuduk',
#  'zhangjiakou',
#  'sumbawa',
#  'melipilla',
#  'fallingbostel',
#  'kiama',
#  'sakakah',
#  'ardakan',
#  'terrace bay',
#  'sirnak',
#  'honningsvag',
#  'bograd',
#  'boundiali',
#  'rabat',
#  'assiniboia',
#  'smolenka',
#  'sibu',
#  'eldikan',
#  'baykit',
#  'jijiga',
#  'awbari']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=ce05151347571195cff46ac169e11d17&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | catalina
# Processing Record 4 of Set 1 | kamenka
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | manta
# Processing Record 7 of Set 1 | tutoia
# Processing Record 8 of Set 1 | huanren
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | vega de alatorre
# Processing Record 11 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 12 of Set 1 | krumbach
# Processing Record 13 of Set 1 | dhidhdhoo
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | lamar
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | caravelas
# Processing Record 18 of Set 1 | hobyo
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 1 | progreso
# Processing Record 23 of Set 1 | kieta
# Processing Record 24 of Set 1 | faanui
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | sekondi
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | saint-francois
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | san carlos de bariloche
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | puerto escondido
# Processing Record 43 of Set 1 | koyilandi
# City not found. Skipping...
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | praya
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | sabha
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | poronaysk
# Processing Record 0 of Set 2 | hirara
# Processing Record 1 of Set 2 | necochea
# Processing Record 2 of Set 2 | charters towers
# Processing Record 3 of Set 2 | bathsheba
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | buala
# Processing Record 6 of Set 2 | hammerfest
# Processing Record 7 of Set 2 | lagunas
# Processing Record 8 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | sibolga
# Processing Record 12 of Set 2 | berbera
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | alyangula
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | agucadoura
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | san luis
# Processing Record 20 of Set 2 | gallup
# Processing Record 21 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | bouna
# Processing Record 25 of Set 2 | alta floresta
# Processing Record 26 of Set 2 | luoyang
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | prince rupert
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | qui nhon
# Processing Record 36 of Set 2 | dire dawa
# Processing Record 37 of Set 2 | nouakchott
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | serta
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | raga
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | mittagong
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 0 of Set 3 | rovenki
# Processing Record 1 of Set 3 | manoel urbano
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | antalaha
# Processing Record 4 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | puerto maldonado
# Processing Record 9 of Set 3 | marawi
# Processing Record 10 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 3 | gorontalo
# Processing Record 12 of Set 3 | narsaq
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | udachnyy
# Processing Record 15 of Set 3 | lafia
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | xining
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | toora-khem
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | rocha
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | punta arenas
# Processing Record 30 of Set 3 | midland
# Processing Record 31 of Set 3 | grand-santi
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | port hedland
# Processing Record 34 of Set 3 | villazon
# Processing Record 35 of Set 3 | dingle
# Processing Record 36 of Set 3 | bontang
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | yar-sale
# Processing Record 39 of Set 3 | kosa
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | boa vista
# Processing Record 42 of Set 3 | butaritari
# Processing Record 43 of Set 3 | sulangan
# Processing Record 44 of Set 3 | north myrtle beach
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | vardo
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | san quintin
# Processing Record 49 of Set 3 | port-gentil
# Processing Record 0 of Set 4 | axim
# Processing Record 1 of Set 4 | morehead
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | nouadhibou
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | asind
# Processing Record 6 of Set 4 | kanniyakumari
# Processing Record 7 of Set 4 | guarapari
# Processing Record 8 of Set 4 | megion
# Processing Record 9 of Set 4 | nemuro
# Processing Record 10 of Set 4 | atambua
# Processing Record 11 of Set 4 | sioux lookout
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | kharitonovo
# Processing Record 14 of Set 4 | zuwarah
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | paka
# Processing Record 17 of Set 4 | ouesso
# Processing Record 18 of Set 4 | moree
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | antimakhia
# City not found. Skipping...
# Processing Record 23 of Set 4 | neiafu
# Processing Record 24 of Set 4 | maralal
# Processing Record 25 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | omsukchan
# Processing Record 30 of Set 4 | te anau
# Processing Record 31 of Set 4 | port keats
# Processing Record 32 of Set 4 | causapscal
# Processing Record 33 of Set 4 | berdigestyakh
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | zarand
# Processing Record 39 of Set 4 | puerto ayora
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | les cayes
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | tuatapere
# Processing Record 45 of Set 4 | tevriz
# Processing Record 46 of Set 4 | road town
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | goderich
# Processing Record 49 of Set 4 | mollendo
# Processing Record 0 of Set 5 | le vauclin
# Processing Record 1 of Set 5 | solnechnyy
# Processing Record 2 of Set 5 | russkaya polyana
# Processing Record 3 of Set 5 | constitucion
# Processing Record 4 of Set 5 | moindou
# Processing Record 5 of Set 5 | luwuk
# Processing Record 6 of Set 5 | oktyabrskiy
# Processing Record 7 of Set 5 | ibb
# Processing Record 8 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 9 of Set 5 | kampene
# Processing Record 10 of Set 5 | toma
# Processing Record 11 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | fredericksburg
# Processing Record 15 of Set 5 | madison
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | huarmey
# Processing Record 18 of Set 5 | ribas do rio pardo
# Processing Record 19 of Set 5 | fallon
# Processing Record 20 of Set 5 | aripuana
# Processing Record 21 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 5 | vaini
# Processing Record 23 of Set 5 | doctor cecilio baez
# Processing Record 24 of Set 5 | brae
# Processing Record 25 of Set 5 | broome
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | ayutuxtepeque
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | bonthe
# Processing Record 32 of Set 5 | wajima
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | kurilsk
# Processing Record 35 of Set 5 | kapit
# Processing Record 36 of Set 5 | mapimi
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | mogadishu
# Processing Record 39 of Set 5 | karratha
# Processing Record 40 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 5 | nabire
# Processing Record 43 of Set 5 | colborne
# Processing Record 44 of Set 5 | nhulunbuy
# Processing Record 45 of Set 5 | verkhnetulomskiy
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | wronki
# Processing Record 48 of Set 5 | kirensk
# Processing Record 49 of Set 5 | saquisili
# Processing Record 0 of Set 6 | san policarpo
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | hermanus
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | pangnirtung
# Processing Record 6 of Set 6 | la ronge
# Processing Record 7 of Set 6 | itacoatiara
# Processing Record 8 of Set 6 | finschhafen
# Processing Record 9 of Set 6 | copiapo
# Processing Record 10 of Set 6 | holme
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | tecate
# Processing Record 13 of Set 6 | omboue
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | alpena
# Processing Record 16 of Set 6 | kollam
# Processing Record 17 of Set 6 | namibe
# Processing Record 18 of Set 6 | lahuachaca
# Processing Record 19 of Set 6 | saint-joseph
# Processing Record 20 of Set 6 | were ilu
# Processing Record 21 of Set 6 | tahe
# Processing Record 22 of Set 6 | ballina
# Processing Record 23 of Set 6 | seoul
# Processing Record 24 of Set 6 | aklavik
# Processing Record 25 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | zyryanka
# Processing Record 27 of Set 6 | vangaindrano
# Processing Record 28 of Set 6 | bay roberts
# Processing Record 29 of Set 6 | thousand oaks
# Processing Record 30 of Set 6 | lima
# Processing Record 31 of Set 6 | grants
# Processing Record 32 of Set 6 | correntina
# Processing Record 33 of Set 6 | lakes entrance
# Processing Record 34 of Set 6 | amot
# Processing Record 35 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 36 of Set 6 | mersing
# Processing Record 37 of Set 6 | kankakee
# Processing Record 38 of Set 6 | dhrangadhra
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | elbistan
# Processing Record 41 of Set 6 | lovozero
# Processing Record 42 of Set 6 | amarillo
# Processing Record 43 of Set 6 | oistins
# Processing Record 44 of Set 6 | cache creek
# Processing Record 45 of Set 6 | xai-xai
# Processing Record 46 of Set 6 | altamira
# Processing Record 47 of Set 6 | chapais
# Processing Record 48 of Set 6 | klamath falls
# Processing Record 49 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 7 | yeppoon
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | thunder bay
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | kutum
# Processing Record 6 of Set 7 | deputatskiy
# Processing Record 7 of Set 7 | qinzhou
# Processing Record 8 of Set 7 | bell ville
# Processing Record 9 of Set 7 | bandarbeyla
# Processing Record 10 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 7 | camabatela
# Processing Record 12 of Set 7 | san lorenzo
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | nanjangud
# Processing Record 15 of Set 7 | sechura
# Processing Record 16 of Set 7 | pedro carbo
# Processing Record 17 of Set 7 | hof
# Processing Record 18 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 7 | clyde river
# Processing Record 20 of Set 7 | cabo san lucas
# Processing Record 21 of Set 7 | key largo
# Processing Record 22 of Set 7 | chiredzi
# Processing Record 23 of Set 7 | half moon bay
# Processing Record 24 of Set 7 | wynyard
# Processing Record 25 of Set 7 | rapid valley
# Processing Record 26 of Set 7 | verkhoyansk
# Processing Record 27 of Set 7 | benghazi
# Processing Record 28 of Set 7 | jinchang
# Processing Record 29 of Set 7 | okato
# Processing Record 30 of Set 7 | launceston
# Processing Record 31 of Set 7 | changde
# Processing Record 32 of Set 7 | piterka
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | tambura
# Processing Record 35 of Set 7 | kyzyl-suu
# Processing Record 36 of Set 7 | melville
# Processing Record 37 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | vera cruz
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | zlobin
# Processing Record 42 of Set 7 | pacific grove
# Processing Record 43 of Set 7 | black diamond
# Processing Record 44 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 7 | clearwater
# Processing Record 46 of Set 7 | sokolo
# Processing Record 47 of Set 7 | helena
# Processing Record 48 of Set 7 | waingapu
# Processing Record 49 of Set 7 | adrar
# Processing Record 0 of Set 8 | liminangcong
# City not found. Skipping...
# Processing Record 1 of Set 8 | akdepe
# Processing Record 2 of Set 8 | hambantota
# Processing Record 3 of Set 8 | bodden town
# Processing Record 4 of Set 8 | jawhar
# Processing Record 5 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 8 | ricardo palma
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | singkang
# Processing Record 9 of Set 8 | plettenberg bay
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | ribeira grande
# Processing Record 12 of Set 8 | umm lajj
# Processing Record 13 of Set 8 | terrak
# Processing Record 14 of Set 8 | lasa
# Processing Record 15 of Set 8 | avarua
# Processing Record 16 of Set 8 | carballo
# Processing Record 17 of Set 8 | nkhotakota
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | port lincoln
# Processing Record 20 of Set 8 | mayo
# Processing Record 21 of Set 8 | opportunity
# Processing Record 22 of Set 8 | ransang
# Processing Record 23 of Set 8 | amlame
# Processing Record 24 of Set 8 | urubicha
# Processing Record 25 of Set 8 | nola
# Processing Record 26 of Set 8 | sao filipe
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | emerald
# Processing Record 29 of Set 8 | torbay
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | puerto madryn
# Processing Record 32 of Set 8 | nome
# Processing Record 33 of Set 8 | fukue
# Processing Record 34 of Set 8 | salalah
# Processing Record 35 of Set 8 | gazojak
# Processing Record 36 of Set 8 | nantucket
# Processing Record 37 of Set 8 | quzhou
# Processing Record 38 of Set 8 | santa fe
# Processing Record 39 of Set 8 | savelugu
# Processing Record 40 of Set 8 | belaya gora
# Processing Record 41 of Set 8 | partsa
# Processing Record 42 of Set 8 | champerico
# Processing Record 43 of Set 8 | coolum beach
# Processing Record 44 of Set 8 | zhuanghe
# Processing Record 45 of Set 8 | popondetta
# Processing Record 46 of Set 8 | kurchum
# Processing Record 47 of Set 8 | lusambo
# Processing Record 48 of Set 8 | dicabisagan
# Processing Record 49 of Set 8 | nanakuli
# Processing Record 0 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 9 | ganzhou
# Processing Record 2 of Set 9 | helong
# Processing Record 3 of Set 9 | college
# Processing Record 4 of Set 9 | noumea
# Processing Record 5 of Set 9 | martinho campos
# Processing Record 6 of Set 9 | zapolyarnyy
# Processing Record 7 of Set 9 | nioro
# Processing Record 8 of Set 9 | jining
# Processing Record 9 of Set 9 | sangmelima
# Processing Record 10 of Set 9 | sokoni
# Processing Record 11 of Set 9 | ahipara
# Processing Record 12 of Set 9 | nanfeng
# Processing Record 13 of Set 9 | togur
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | jagraon
# Processing Record 16 of Set 9 | waddan
# Processing Record 17 of Set 9 | ukiah
# Processing Record 18 of Set 9 | inverell
# Processing Record 19 of Set 9 | olavarria
# Processing Record 20 of Set 9 | gzhatsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | barao de melgaco
# Processing Record 22 of Set 9 | kamaishi
# Processing Record 23 of Set 9 | la romana
# Processing Record 24 of Set 9 | tessalit
# Processing Record 25 of Set 9 | ratnagiri
# Processing Record 26 of Set 9 | valle de allende
# Processing Record 27 of Set 9 | paamiut
# Processing Record 28 of Set 9 | turan
# Processing Record 29 of Set 9 | dabakala
# Processing Record 30 of Set 9 | abilene
# Processing Record 31 of Set 9 | spearfish
# Processing Record 32 of Set 9 | hovd
# Processing Record 33 of Set 9 | lata
# Processing Record 34 of Set 9 | beloha
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | copparo
# Processing Record 37 of Set 9 | tahta
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | yerbogachen
# Processing Record 41 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 9 | roebourne
# Processing Record 43 of Set 9 | deoli
# Processing Record 44 of Set 9 | mehran
# Processing Record 45 of Set 9 | pangai
# Processing Record 46 of Set 9 | derzhavinsk
# Processing Record 47 of Set 9 | port macquarie
# Processing Record 48 of Set 9 | comodoro rivadavia
# Processing Record 49 of Set 9 | ugoofaaru
# Processing Record 0 of Set 10 | poum
# Processing Record 1 of Set 10 | sisimiut
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | jiuquan
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | takoradi
# Processing Record 6 of Set 10 | ilulissat
# Processing Record 7 of Set 10 | vanavara
# Processing Record 8 of Set 10 | zulueta
# Processing Record 9 of Set 10 | rodez
# Processing Record 10 of Set 10 | timbiqui
# Processing Record 11 of Set 10 | cabinda
# Processing Record 12 of Set 10 | hue
# Processing Record 13 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 10 | roma
# Processing Record 15 of Set 10 | tonj
# Processing Record 16 of Set 10 | havoysund
# Processing Record 17 of Set 10 | nedjo
# Processing Record 18 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 10 | cap malheureux
# Processing Record 20 of Set 10 | kokoda
# Processing Record 21 of Set 10 | banda aceh
# Processing Record 22 of Set 10 | sebeta
# Processing Record 23 of Set 10 | jatibonico
# Processing Record 24 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 25 of Set 10 | statesboro
# Processing Record 26 of Set 10 | teknaf
# Processing Record 27 of Set 10 | daru
# Processing Record 28 of Set 10 | gorin
# Processing Record 29 of Set 10 | nosy varika
# Processing Record 30 of Set 10 | sola
# Processing Record 31 of Set 10 | vestmanna
# Processing Record 32 of Set 10 | linhai
# Processing Record 33 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 34 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 10 | lac
# Processing Record 36 of Set 10 | smithers
# Processing Record 37 of Set 10 | turbat
# Processing Record 38 of Set 10 | longyearbyen
# Processing Record 39 of Set 10 | guymon
# Processing Record 40 of Set 10 | vavoua
# Processing Record 41 of Set 10 | shenjiamen
# Processing Record 42 of Set 10 | tabory
# Processing Record 43 of Set 10 | lang son
# Processing Record 44 of Set 10 | isangel
# Processing Record 45 of Set 10 | prachuap khiri khan
# Processing Record 46 of Set 10 | findlay
# Processing Record 47 of Set 10 | chulym
# Processing Record 48 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 10 | mirnyy
# Processing Record 0 of Set 11 | ust-tsilma
# Processing Record 1 of Set 11 | kirakira
# Processing Record 2 of Set 11 | kenora
# Processing Record 3 of Set 11 | alice springs
# Processing Record 4 of Set 11 | volosovo
# Processing Record 5 of Set 11 | shingu
# Processing Record 6 of Set 11 | yatou
# Processing Record 7 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 11 | port augusta
# Processing Record 9 of Set 11 | viedma
# Processing Record 10 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 11 | sao miguel
# Processing Record 12 of Set 11 | leshukonskoye
# Processing Record 13 of Set 11 | petatlan
# Processing Record 14 of Set 11 | hofn
# Processing Record 15 of Set 11 | itaqui
# Processing Record 16 of Set 11 | tevaitoa
# Processing Record 17 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 11 | quatre cocos
# Processing Record 19 of Set 11 | oxelosund
# Processing Record 20 of Set 11 | khani
# Processing Record 21 of Set 11 | igarka
# Processing Record 22 of Set 11 | upata
# Processing Record 23 of Set 11 | batemans bay
# Processing Record 24 of Set 11 | yagodnoye
# Processing Record 25 of Set 11 | akwatia
# Processing Record 26 of Set 11 | warangal
# Processing Record 27 of Set 11 | nishihara
# Processing Record 28 of Set 11 | cockburn town
# Processing Record 29 of Set 11 | chara
# Processing Record 30 of Set 11 | cheyenne
# Processing Record 31 of Set 11 | jacmel
# Processing Record 32 of Set 11 | nusaybin
# Processing Record 33 of Set 11 | olafsvik
# Processing Record 34 of Set 11 | gorshechnoye
# Processing Record 35 of Set 11 | bilopillya
# Processing Record 36 of Set 11 | colares
# Processing Record 37 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 11 | marsa matruh
# Processing Record 39 of Set 11 | cortez
# Processing Record 40 of Set 11 | castellammare del golfo
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | ponta delgada
# Processing Record 43 of Set 11 | dano
# Processing Record 44 of Set 11 | kloulklubed
# Processing Record 45 of Set 11 | maldonado
# Processing Record 46 of Set 11 | tomatlan
# Processing Record 47 of Set 11 | abu dhabi
# Processing Record 48 of Set 11 | cessnock
# Processing Record 49 of Set 11 | callaway
# Processing Record 0 of Set 12 | mulege
# Processing Record 1 of Set 12 | bato
# Processing Record 2 of Set 12 | vila do maio
# Processing Record 3 of Set 12 | sobolevo
# Processing Record 4 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | saldanha
# Processing Record 6 of Set 12 | talaya
# Processing Record 7 of Set 12 | jishou
# Processing Record 8 of Set 12 | vaitape
# Processing Record 9 of Set 12 | quelimane
# Processing Record 10 of Set 12 | bossangoa
# Processing Record 11 of Set 12 | batagay
# Processing Record 12 of Set 12 | ati
# Processing Record 13 of Set 12 | luba
# Processing Record 14 of Set 12 | peniche
# Processing Record 15 of Set 12 | presidencia roque saenz pena
# Processing Record 16 of Set 12 | lambarene
# Processing Record 17 of Set 12 | tunceli
# Processing Record 18 of Set 12 | sao marcos
# Processing Record 19 of Set 12 | slavgorodskoye
# Processing Record 20 of Set 12 | hannoversch munden
# Processing Record 21 of Set 12 | inzhavino
# Processing Record 22 of Set 12 | labuhan
# Processing Record 23 of Set 12 | northam
# Processing Record 24 of Set 12 | duku
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | zhoucheng
# Processing Record 27 of Set 12 | norman wells
# Processing Record 28 of Set 12 | tibacuy
# Processing Record 29 of Set 12 | horsham
# Processing Record 30 of Set 12 | kapasan
# Processing Record 31 of Set 12 | carutapera
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | bijar
# Processing Record 34 of Set 12 | aneho
# Processing Record 35 of Set 12 | mattru
# Processing Record 36 of Set 12 | dukat
# Processing Record 37 of Set 12 | egvekinot
# Processing Record 38 of Set 12 | joshimath
# Processing Record 39 of Set 12 | monroe
# Processing Record 40 of Set 12 | macusani
# Processing Record 41 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 42 of Set 12 | altinopolis
# Processing Record 43 of Set 12 | dewas
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | hami
# Processing Record 46 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 12 | dryden
# Processing Record 48 of Set 12 | chino valley
# Processing Record 49 of Set 12 | blyznyuky
# Processing Record 0 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 13 | la ligua
# Processing Record 2 of Set 13 | ambilobe
# Processing Record 3 of Set 13 | henties bay
# Processing Record 4 of Set 13 | ostersund
# Processing Record 5 of Set 13 | agha jari
# City not found. Skipping...
# Processing Record 6 of Set 13 | luganville
# Processing Record 7 of Set 13 | the pas
# Processing Record 8 of Set 13 | leonidovo
# Processing Record 9 of Set 13 | aracuai
# Processing Record 10 of Set 13 | forbes
# Processing Record 11 of Set 13 | shubarkuduk
# Processing Record 12 of Set 13 | zhangjiakou
# Processing Record 13 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 13 | melipilla
# Processing Record 15 of Set 13 | fallingbostel
# Processing Record 16 of Set 13 | kiama
# Processing Record 17 of Set 13 | sakakah
# Processing Record 18 of Set 13 | ardakan
# Processing Record 19 of Set 13 | terrace bay
# Processing Record 20 of Set 13 | sirnak
# Processing Record 21 of Set 13 | honningsvag
# Processing Record 22 of Set 13 | bograd
# Processing Record 23 of Set 13 | boundiali
# Processing Record 24 of Set 13 | rabat
# Processing Record 25 of Set 13 | assiniboia
# Processing Record 26 of Set 13 | smolenka
# Processing Record 27 of Set 13 | sibu
# Processing Record 28 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 13 | baykit
# Processing Record 30 of Set 13 | jijiga
# Processing Record 31 of Set 13 | awbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saskylakh  71.9167  114.0833      5.26        56          97        5.19
# 1   catalina  32.5056 -110.9211     28.94        15          32        0.45
# 2    kamenka  51.3223   42.7678     18.04        83          76        5.15
# 3  busselton -33.6500  115.3333     14.63        65          89        6.92
# 4      manta  -0.9500  -80.7333     28.88        89          75        7.60
#
#   Country        Date
# 0      RU  1686414307
# 1      US  1686414307
# 2      RU  1686414308
# 3      AU  1686414308
# 4      EC  1686414308

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        saskylakh  71.9167  114.0833      5.26        56          97
# 1         catalina  32.5056 -110.9211     28.94        15          32
# 2          kamenka  51.3223   42.7678     18.04        83          76
# 3        busselton -33.6500  115.3333     14.63        65          89
# 4            manta  -0.9500  -80.7333     28.88        89          75
#
#          Wind Speed Country        Date
# City_ID
# 0              5.19      RU  1686414307
# 1              0.45      US  1686414307
# 2              5.15      RU  1686414308
# 3              6.92      AU  1686414308
# 4              7.60      EC  1686414308

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df["Lat"]
lng = city_data_df["Lng"]
temp = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

plt.scatter(
    lat,
    lng,
    edgecolor ="black",
    linewidths =1,
    marker = "o",
    alpha = 0.9,
    label = "Cities"
    
)

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({str(time.strftime('%Y-%m-%d'))})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    lat,
    humidity,
    edgecolor ="black",
    linewidths =1,
    marker = "o",
    alpha = 0.9,
    label = "Cities"
    
)


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({str(time.strftime('%Y-%m-%d'))})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    lat,
    cloudiness,
    edgecolor ="black",
    linewidths =1,
    marker = "o",
    alpha = 0.9,
    label = "Cities"
    
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({str(time.strftime('%Y-%m-%d'))})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    lat,
    wind_speed,
    edgecolor ="black",
    linewidths =1,
    marker = "o",
    alpha = 0.9,
    label = "Cities"
    
)


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({str(time.strftime('%Y-%m-%d'))})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x, y, title, text_coord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress = x * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x,y)
    plt.plot(x, regress, "r-")
    plt.annotate(line_eq, text_coord, fontsize=12, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print("The r-value is", rvalue**2)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[lat >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               saskylakh  71.9167  114.0833      5.26        56          97
# 1                catalina  32.5056 -110.9211     28.94        15          32
# 2                 kamenka  51.3223   42.7678     18.04        83          76
# 6                 huanren  41.2647  125.3667     12.82        99         100
# 8        vega de alatorre  20.0333  -96.6333     30.79        70          17
#
#          Wind Speed Country        Date
# City_ID
# 0              5.19      RU  1686414307
# 1              0.45      US  1686414307
# 2              5.15      RU  1686414308
# 6              0.40      CN  1686414308
# 8              2.68      MX  1686414308

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[lat < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3        busselton -33.6500  115.3333     14.63        65          89
# 4            manta  -0.9500  -80.7333     28.88        89          75
# 5           tutoia  -2.7619  -42.2744     30.34        61           7
# 7          ushuaia -54.8000  -68.3000      4.81        75          20
# 13         mataura -46.1927  168.8643      1.87        86          49
#
#          Wind Speed Country        Date
# City_ID
# 3              6.92      AU  1686414308
# 4              7.60      EC  1686414308
# 5              5.07      BR  1686414308
# 7              9.26      AR  1686414063
# 13             1.66      NZ  1686414309

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]
plot_linear_regression(x,y, "Max Temp", (8,-8))
# Out:
# The r-value is 0.6028777988313384

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]
plot_linear_regression(x,y, "Max Temp", (-55,36))
# Out:
# The r-value is 0.6525507781456226

# %% [markdown]
# **Discussion about the linear relationship:** The max temperature is generally higher in both hemispheres. Latitude is 0 and it gets lower as you get further away from zero.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]
plot_linear_regression(x,y, "Humidity", (40,15))
# Out:
# The r-value is 0.000209197513806675

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]
plot_linear_regression(x,y, "Humidity", (-50,20))
# Out:
# The r-value is 0.007802434260986214

# %% [markdown]
# **Discussion about the linear relationship:** the humidity increases when you go north

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Cloudiness"]
plot_linear_regression(x,y, "Cloudiness", (40,10))
# Out:
# The r-value is 0.0005115717537060312

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Cloudiness"]
plot_linear_regression(x,y, "Cloudiness", (-30,30))
# Out:
# The r-value is 0.050787865052296745

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness seems to increase as you go further north

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Wind Speed"]
plot_linear_regression(x,y, "Wind Speed", (10,13))
# Out:
# The r-value is 0.00043014719705414907

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Wind Speed"]
plot_linear_regression(x,y, "Wind Speed", (-50,13))
# Out:
# The r-value is 0.04043096183435767

# %% [markdown]
# **Discussion about the linear relationship:** the winds seem to be lower as closer to the latitude of zero
